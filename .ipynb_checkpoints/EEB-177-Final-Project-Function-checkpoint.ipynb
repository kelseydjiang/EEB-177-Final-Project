# %%
Elasmobranchii_data = {}
ff = open(("new_elasmobranchii_data.csv"), "r", encoding = "ISO-8859-15")
ss = ff.readlines()
for line in ss:
    EB_name = line.split(",")[0]
    EB_rank = line.split(",")[0]
    Elasmobranchii_data[EB_name] = EB_rank
ff.close()

# %%
def makeElasmobranchiiDict(filename):
    # this function opens the data file from Elasmobranchii and extracts the name and rank as a dictionary.
    ElasmobranchiiDict = {}
    fobj = open(filename,"r", encoding = "ISO-8859-15") # open the file 
    all_records = fobj.readlines() [1:] # read the file, all_records is a list
    for line in all_records:
        record_elements = line.split(",")
        EB_name = record_elements[0]
        EB_rank = record_elements[1]
        ElasmobranchiiDict[EB_name] = EB_rank
    # name = line.split(",") splits it into a new list that is ordered correctly  
    # split lines on comma
    # stick species and family into ElasmobranchiiDict
    
    return ElasmobranchiiDict

# %%
makeElasmobranchiiDict("new_elasmobranchii_data.csv")
# Out:
# {' obsolete variant of"': '"Aetobatus"',
#  ' recombined as"': '"Isurus desorii"',
#  ' species not entered"': '"Carcharias"',
#  '"Abdounia"': '"genus"',
#  '"Acanthoscyllium"': '"genus"',
#  '"Acrodus flemingianus"': '"species"',
#  '"Acrodus jaeckeli"': '"species"',
#  '"Acrodus lateralis"': '"species"',
#  '"Acrodus levis"': '"species"',
#  '"Acrodus spitzbergensis"': '"species"',
#  '"Acrodus"': '"genus"',
#  '"Acrorhizodus khoratensis"': '"species"',
#  '"Aetobatis irregularis"': '"species"',
#  '"Aetobatus arcuatus"': '"species"',
#  '"Aetobatus"': '"genus"',
#  '"Aktaua"': '"genus"',
#  '"Almascyllium"': '"genus"',
#  '"Alopias latidens"': '"species"',
#  '"Alopias superciliosus"': '"species"',
#  '"Alopias vulpinus"': '"species"',
#  '"Alopias"': '"genus"',
#  '"Amelacanthus sulcatus"': '"species"',
#  '"Amelacanthus"': '"genus"',
#  '"Annulicorona pyramidalis"': '"species"',
#  '"Anomotodon plicatus"': '"species"',
#  '"Anomotodon"': '"genus"',
# ...

# %%
# open the file
infile = "/home/eeb177-student/Desktop/eeb-177/EEB-177-Final-Project/reformatted-Elasmobranchii-data.csv"
with open(infile, 'r') as ff:
    Elasmobranchii_recs = ff.readlines()

# %%
#use defaultdict
from collections import defaultdict

species_ranges = defaultdict(list)

# make a dictionary
for line in Elasmobranchii_recs:
    species = line.split('","')[5] #add single quotes around the double to get rid of the quotation marks
    minage = line.split('","')[15]
    maxage = line.split('","')[14]
    total_age = (float(maxage) - float(minage))
    print(total_age)
    
    species_ranges[species].append(total_age)
# Out:
# 6.099999999999994
# 6.099999999999994
# 17.697000000000003
# 17.697000000000003
# 17.697000000000003
# 17.697000000000003
# 17.697000000000003
# 17.697000000000003
# 17.697000000000003
# 44.5
# 6.099999999999994
# 11.399999999999999
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 8.200000000000003
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# 17.599999999999994
# ...

# %%
output = open("Elasmobranchii_ranges.csv", "w")

for key in species_ranges.keys():
    ages = species_ranges[key]
    minage = min(ages)
    maxage = max(ages)
    genus = key.split(" ")[0]
    species = key
    output = "{},{},{}\n".format(genus, species, total_age)
    print(output)
# Out:
# Carchariolamna,Carchariolamna heroni,5.369999999999997
#
# Labrilancea,Labrilancea glabrisubcuspis,5.369999999999997
#
# Paraorthacodus,Paraorthacodus aff. nerviensis,5.369999999999997
#
# Dalatias,Dalatias sp.,5.369999999999997
#
# Acrodus,Acrodus substraitus,5.369999999999997
#
# Glikmanius,Glikmanius cf. myachkovensis,5.369999999999997
#
# Physogaleus,Physogaleus sp.,5.369999999999997
#
# Lissodus,Lissodus sp.,5.369999999999997
#
# Parapalaeobates,Parapalaeobates sp.,5.369999999999997
#
# Neoselachii,Neoselachii ? indet.,5.369999999999997
#
# Pristis,Pristis ? cf. lathami,5.369999999999997
#
# Nebrius,Nebrius delfortriei,5.369999999999997
#
# Pararhincodon,Pararhincodon sp.,5.369999999999997
#
# Lamna,Lamna rapax,5.369999999999997
#
# Hypolophodon,Hypolophodon sp.,5.369999999999997
#
# Erguitaia,Erguitaia sp.,5.369999999999997
#
# Pseudocarcharias,Pseudocarcharias sp.,5.369999999999997
#
# Cretalamna,Cretalamna appendiculata,5.369999999999997
#
# ...

# %% [markdown]
# # Project Outline - Elasmobranchii

# %% [markdown]
# 1. Start by separating the data so that only the accepted organisms are paired with its classification (genus, family, superorder, species, etc.)
# 2. Grep only those that are listed as species to compare the min age, max age, and total age
# (You can find the total age by substracting the min age from the max age)
# 3. Look at the total age of all the species classified under Elasmobranchii
# 4. Append the total age of each species to a dictionary of all the species listed
# 5. Order the mean age in descending order so that I can see which species had the longest mean age - this could shed light on which species survived the longest or underwent the most evolutionary change to adapt to its environment
# 6. From this order, plot graphs in matplotlib that show the mean age of each species in descending order

# %% [markdown]
# # Sources

# %% [markdown]
# https://academic.oup.com/mbe/article/27/11/2576/1121974/Evolutionary-Origin-and-Phylogeny-of-the-Modern
#
# Jun G. Inoue, Masaki Miya, Kevin Lam, Boon-Hui Tay, Janine A. Danks, Justin Bell, Terrence I. Walker, Byrappa Venkatesh; Evolutionary Origin and Phylogeny of the Modern Holocephalans (Chondrichthyes: Chimaeriformes): A Mitogenomic Perspective. Mol Biol Evol 2010; 27 (11): 2576-2586. doi: 10.1093/molbev/msq147
